# %% [markdown]
# # 16 Simulation showing value of t statistic

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/confidence-intervals-one-sample/estimating-population-mean/v/simulation-showing-value-of-t-statistic?modal=1)

# %% [markdown]
# ![Simulation showing value of t statistic fig 1](./imgs/11-16-01.png)![Simulation showing value of t statistic fig 2](./imgs/11-16-02.png)
