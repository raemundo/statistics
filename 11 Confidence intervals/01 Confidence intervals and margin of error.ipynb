# %% [markdown]
# # 01 Confidence intervals and margin of error

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/confidence-intervals-one-sample/introduction-to-confidence-intervals/v/confidence-intervals-and-margin-of-error?modal=1)

# %% [markdown]
# ![Confidence intervals and margin of error fig 1](./imgs/11-01-01.png)

# %%
stats.norm.interval(0.95, loc=0.54, scale=0.05)
# Out:
# (0.44200180077299733, 0.6379981992270027)
