# %% [markdown]
# # 06 Classifying shapes of distributions

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# <img src="imgs/Screen Shot 2019-08-12 at 11.10.39 AM.png">
