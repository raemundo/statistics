# %% [markdown]
# # 05 Normal conditions for sampling distributions of sample proportions

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/sampling-distribution-ap/sampling-distribution-proportion/v/normal-conditions-for-sampling-distributions-of-sample-proportions?modal=1)

# %% [markdown]
# $$ np \geq 10  \quad n(1 - p) \geq 10 \quad \Rightarrow \quad \hat{p} $$

# %% [markdown]
# ![Normal conditions for sampling distributions of sample proportions fig 1](./imgs/10-05-01.png)![Normal conditions for sampling distributions of sample proportions fig 2](./imgs/10-05-02.png)
