# %% [markdown]
# # 06 Probability of sample proportions example

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/sampling-distribution-ap/sampling-distribution-proportion/v/probability-of-sample-proportions-example?modal=1)

# %% [markdown]
# ![Probability of sample proportions example fig 1](./imgs/10-06-01.png)![Probability of sample proportions example fig 2](./imgs/10-06-02.png)

# %%
n = 160
p = 0.15
mu = p
sigma = np.sqrt(p*(1-p)/n)

# %%
1 - stats.norm.cdf(0.10, loc=mu, scale=sigma) # why?
# Out:
# 0.9617387497624703
