# %% [markdown]
# # 16 Threshold for low percentile

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/density-curves-normal-distribution-ap/normal-distributions-calculations/v/threshold-for-low-percentile?modal=1)

# %% [markdown]
# ![Threshold for low percentile fig 1](./imgs/04-16-01.png)

# %%
print(stats.norm.ppf(0.10, loc=185, scale=11))
# Out:
# 170.9029327790094
