# %%
import numpy as np 
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/density-curves-normal-distribution-ap/density-curves/v/density-curves?modal=1)

# %% [markdown]
# <img src="imgs/Screen Shot 2019-08-12 at 8.37.13 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 8.37.40 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 8.37.57 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 8.39.23 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 8.40.00 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 8.41.17 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 8.43.10 PM.png">

# %%
x = Series([0.5, 0.7, 2.1, 2.2, 2.9, 3.2, 3.2, 3.3, 3.7, 4.5, 4.6, 4.8, 5.2, 5.3, 6.7, 8.1])

# %%
x.plot(kind='hist')

# %%
x.plot(kind='density')

# %%
sns.distplot(x)

# %%
# https://stackoverflow.com/questions/4150171/how-to-create-a-density-plot-in-matplotlib
density = stats.gaussian_kde(x)
xs = np.arange(0., 8, .1)
density.covariance_factor = lambda : .25 # to remove
density._compute_covariance() # to remove
plt.plot(xs,density(xs))
plt.show()
