# %% [markdown]
# # 09 Worked example finding area under density curves

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/density-curves-normal-distribution-ap/density-curves/v/worked-example-finding-area-under-density-curves?modal=1)

# %% [markdown]
# ![Worked example finding area under density curves fig 1](./imgs/04-09-01.png)![Worked example finding area under density curves fig 2](./imgs/04-09-02.png)

# %%
x = Series(25 * [1] + 50 * [2] + 75 * [3])
x.plot(kind='density', xlim=[0, 3])

# %%
y = Series(2 * [3.5] + 4 * [4] + 4 * [5] + 4 * [6])
x.plot(kind='density')

# %%
# find a way to plot 'em better
