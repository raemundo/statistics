# %% [markdown]
# # 14 Standard normal table (optional)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats

# %% [markdown]
# [![IMAGE ALT TEXT HERE](https://img.youtube.com/vi/kA_b9NlGUls/0.jpg)](https://www.youtube.com/watch?v=kA_b9NlGUls)

# %% [markdown]
# [How to Use and Create a Z-Table (Standard Normal Table)](https://towardsdatascience.com/how-to-use-and-create-a-z-table-standard-normal-table-240e21f36e53)
