# %% [markdown]
# # 13 Can causality be established from this study

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/gathering-data-ap/statistics-experiments/v/causality-from-study?modal=1)

# %% [markdown]
# ![Can causality be established from this study fig 1](./imgs/06-13-01.png)
