# %% [markdown]
# # 04 Example of undercoverage introducing bias

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/gathering-data-ap/sampling-observational-studies/v/example-of-under-coverage-introducing-bias?modal=1)

# %% [markdown]
# ![Example of undercoverage introducing bias fig 1](./imgs/06-04-01.png)![Example of undercoverage introducing bias fig 2](./imgs/06-04-02.png)
