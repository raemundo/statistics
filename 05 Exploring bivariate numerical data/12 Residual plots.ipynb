# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/bivariate-data-ap/assessing-fit-least-squares-regression/v/residual-plots?modal=1)

# %% [markdown]
# <img src="imgs/Screen Shot 2019-08-12 at 11.54.31 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 11.54.56 PM.png">
# <img src="imgs/Screen Shot 2019-08-12 at 11.55.13 PM.png">

# %%
x = np.array([1, 2, 2, 3])
y = np.array([1, 2, 3, 6])

# %%
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x, y)

# %%
yhat = intercept + slope * x

# %% [markdown]
# $$ residual = actual - predict  $$
# $$ residual = y - \hat{y} $$

# %%
r = y - yhat

# %%
plt.scatter(x, y, label='Original data')
plt.plot(x, yhat, color='r', label='Fitted line')
plt.legend()
plt.show()

# %%
sns.scatterplot(x, y, label='Original data')
sns.lineplot(x, yhat, color='r', label='Fitted line')

# %%
# residual plot
plt.scatter(x, r)
plt.title('Residual Plot')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

# %%
sns.scatterplot(x, r)
plt.title('Residual Plot')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

# %% [markdown]
# [How do you check the quality of your regression model in Python?](https://towardsdatascience.com/how-do-you-check-the-quality-of-your-regression-model-in-python-fa61759ff685)
