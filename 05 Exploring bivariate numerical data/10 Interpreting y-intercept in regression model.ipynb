# %% [markdown]
# # 10 Interpreting y-intercept in regression model

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/bivariate-data-ap/least-squares-regression/v/interpreting-y-intercept-in-regression-model?modal=1)

# %% [markdown]
# ![Interpreting y-intercept in regression model fig 1](./imgs/05-10-01.png)![Interpreting y-intercept in regression model fig 2](./imgs/05-10-02.png)
