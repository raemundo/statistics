# %% [markdown]
# # 20 Interpreting box plots

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/summarizing-quantitative-data-ap/stats-box-whisker-plots/v/interpreting-box-plots?modal=1)

# %% [markdown]
# ![Interpreting box plots fig 1](./imgs/03-20-01.png)

# %%
# construct the same box plot using different data sets
