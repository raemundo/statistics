# %% [markdown]
# # 06 Estimating a P-value from a simulation

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/significance-tests-one-sample/idea-of-significance-tests/v/estimating-p-value-from-simulation?modal=1)

# %% [markdown]
# ![Estimating a P-value from a simulation fig 1](./imgs/12-06-01.png)![Estimating a P-value from a simulation fig 2](./imgs/12-06-02.png)
