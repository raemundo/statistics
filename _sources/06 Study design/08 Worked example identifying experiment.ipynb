# %% [markdown]
# # 08 Worked example identifying experiment

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/gathering-data-ap/types-of-studies-experimental-vs-observational/v/worked-example-identifying-experiment?modal=1)

# %% [markdown]
# ![Worked example identifying experiment fig 1](./imgs/06-08-01.png)
