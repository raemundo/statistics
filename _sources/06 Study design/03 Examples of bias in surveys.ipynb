# %% [markdown]
# # 03 Examples of bias in surveys

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/gathering-data-ap/sampling-observational-studies/v/examples-of-bias-in-surveys?modal=1)

# %% [markdown]
# ![Examples of bias in surveys fig 1](./imgs/06-03-01.png)![Examples of bias in surveys fig 2](./imgs/06-03-02.png)
