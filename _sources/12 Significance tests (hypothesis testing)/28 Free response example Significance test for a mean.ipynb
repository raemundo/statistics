# %% [markdown]
# # 28 Free response example Significance test for a mean

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/significance-tests-one-sample/tests-about-population-mean/v/ap-statistics-free-response-on-significance-test-for-mean?modal=1)

# %% [markdown]
# ![Free response example Significance test for a mean fig 1](./imgs/12-28-01.png)![Free response example Significance test for a mean fig 2](./imgs/12-28-02.png)

# %%
stats.t.cdf(-1.32, 11)
# Out:
# 0.10682233239922606
