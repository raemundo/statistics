# %% [markdown]
# # 25 Using TI calculator for P-value from t statistic

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/significance-tests-one-sample/tests-about-population-mean/v/using-ti-calculator-for-p-value-from-t-statistic?modal=1)

# %% [markdown]
# ![Using TI calculator for P-value from t statistic fig 1](./imgs/12-25-01.png)![Using TI calculator for P-value from t statistic fig 2](./imgs/12-25-02.png)
