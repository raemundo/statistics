# %% [markdown]
# # 24 Example calculating t statistic for a test about a mean

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/significance-tests-one-sample/tests-about-population-mean/v/example-calculating-t-statistic-for-signficance-test?modal=1)

# %% [markdown]
# ![Example calculating t statistic for a test about a mean fig 1](./imgs/12-24-01.png)
