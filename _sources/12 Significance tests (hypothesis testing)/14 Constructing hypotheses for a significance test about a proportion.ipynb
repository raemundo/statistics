# %% [markdown]
# # 14 Constructing hypotheses for a significance test about a proportion

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/significance-tests-one-sample/tests-about-population-proportion/v/constructing-hypotheses-for-a-significance-test?modal=1)

# %% [markdown]
# ![Constructing hypotheses for a significance test about a proportion fig 1](./imgs/12-14-01.png)![Constructing hypotheses for a significance test about a proportion fig 2](./imgs/12-14-02.png)
