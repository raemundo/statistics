# %% [markdown]
# # 07 Median, mean and skew from density curves

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/density-curves-normal-distribution-ap/density-curves/v/median-mean-and-skew-from-density-curves?modal=1)

# %% [markdown]
# ![Median, mean and skew from density curves fig 1](./imgs/04-07-01.png)

# %%
# find a way to plot these density curves and calculate their median and mean
