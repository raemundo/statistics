# %% [markdown]
# # 06 Classifying shapes of distributions

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# ![Classifying shapes of distributions fig 1](./imgs/02-06-01.png)
