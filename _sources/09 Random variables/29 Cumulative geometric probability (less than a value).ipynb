# %% [markdown]
# # 29 Cumulative geometric probability (less than a value)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/random-variables-ap/geometric-random-variable/v/cumulative-geometric-probability-less-than-a-value?modal=1)

# %% [markdown]
# ![Cumulative geometric probability (less than a value) fig 1](./imgs/09-29-01.png)

# %%
p = 0.1

# %%
np.sum([(1 - p)**i* p for i in range(4)])
# Out:
# 0.34390000000000004

# %%
1 - 0.9 ** 4
# Out:
# 0.3439
