# %% [markdown]
# # 16 Recognizing binomial variables

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/random-variables-ap/binomial-random-variable/v/recognizing-binomial-variables?modal=1)

# %% [markdown]
# ![Recognizing binomial variables fig 1](./imgs/09-16-01.png)![Recognizing binomial variables fig 2](./imgs/09-16-02.png)
