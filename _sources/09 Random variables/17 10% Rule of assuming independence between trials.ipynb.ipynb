# %% [markdown]
# # 17 10% Rule of assuming independence between trials

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/random-variables-ap/binomial-random-variable/v/10-percent-rule-independence?modal=1)

# %% [markdown]
# ![10% Rule of assuming independence between trials fig 1](./imgs/09-17-01.png)
