# %% [markdown]
# # 28 Cumulative geometric probability (greater than a value)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/random-variables-ap/geometric-random-variable/v/cumulative-geometric-probability-greater-than-a-value?modal=1)

# %% [markdown]
# ![Cumulative geometric probability (greater than a value) fig 1](./imgs/09-28-01.png)

# %%
p = 1 - 0.12

# %%
p**4
# Out:
# 0.59969536
