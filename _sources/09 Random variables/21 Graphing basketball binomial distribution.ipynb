# %% [markdown]
# # 21 Graphing basketball binomial distribution

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/random-variables-ap/binomial-random-variable/v/graphing-basketball-binomial-distribution?modal=1)

# %% [markdown]
# ![Free throw binomial probability distribution fig 1](./imgs/09-20-01.png)![Free throw binomial probability distribution fig 2](./imgs/09-20-02.png)![Graphing basketball binomial distribution](./imgs/09-21-01.png)

# %%
n = 6
f = 0.7

# %%
x = range(7)

# %%
y = np.array([special.comb(n, k) * f ** k * (1-f)**(n - k) for k in x])

# %%
y = np.round(y * 100)

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 7 artists>

# %%
binom_data = stats.binom.rvs(n=6, p=0.7, size=1000)

# %%
sns.distplot(binom_data, hist_kws={'alpha': 1})
