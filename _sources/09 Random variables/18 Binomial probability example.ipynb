# %% [markdown]
# # 18 Binomial probability example

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/random-variables-ap/binomial-random-variable/v/probability-of-making-2-shots-in-6-attempts?modal=1)

# %% [markdown]
# ![Binomial probability example fig 1](./imgs/09-18-01.png)

# %%
# find a way to code this too
# review combination

# %%
s = np.random.binomial(1, 0.7, 6) # don't know if that the right way, though
s
# Out:
# array([0, 0, 0, 0, 1, 1])

# %%
p = special.comb(6, 2) * 0.7**2 * 0.3**4

# %%
round(p * 100)
# Out:
# 6.0
