# %% [markdown]
# # 13 Example of hypotheses for paired and two-sample t tests

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/two-sample-inference/two-sample-t-test-means/v/example-of-hypotheses-for-paired-and-2-sample-t-tests?modal=1)

# %% [markdown]
# ![Example of hypotheses for paired and two-sample t tests fig 1](./imgs/13-13-01.png)
