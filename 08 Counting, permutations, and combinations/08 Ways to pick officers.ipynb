# %%
import itertools
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/counting-permutations-and-combinations/permutation-lib/v/permutations-and-combinations-2?modal=1)

# %% [markdown]
# <img src="imgs/Anotación 2020-03-10 094255.png">

# %%
persons = list(range(1, 10, 1))

# %%
p = list(itertools.permutations(persons, 3))

# %%
p
# Out:
# [(1, 2, 3),
#  (1, 2, 4),
#  (1, 2, 5),
#  (1, 2, 6),
#  (1, 2, 7),
#  (1, 2, 8),
#  (1, 2, 9),
#  (1, 3, 2),
#  (1, 3, 4),
#  (1, 3, 5),
#  (1, 3, 6),
#  (1, 3, 7),
#  (1, 3, 8),
#  (1, 3, 9),
#  (1, 4, 2),
#  (1, 4, 3),
#  (1, 4, 5),
#  (1, 4, 6),
#  (1, 4, 7),
#  (1, 4, 8),
#  (1, 4, 9),
#  (1, 5, 2),
#  (1, 5, 3),
#  (1, 5, 4),
#  (1, 5, 6),
#  (1, 5, 7),
#  (1, 5, 8),
#  (1, 5, 9),
#  (1, 6, 2),
#  (1, 6, 3),
#  (1, 6, 4),
#  (1, 6, 5),
#  (1, 6, 7),
#  (1, 6, 8),
#  (1, 6, 9),
#  (1, 7, 2),
#  (1, 7, 3),
#  (1, 7, 4),
#  (1, 7, 5),
#  (1, 7, 6),
#  (1, 7, 8),
#  (1, 7, 9),
#  (1, 8, 2),
#  (1, 8, 3),
#  (1, 8, 4),
#  (1, 8, 5),
#  (1, 8, 6),
#  (1, 8, 7),
#  (1, 8, 9),
#  (1, 9, 2),
#  (1, 9, 3),
#  (1, 9, 4),
#  (1, 9, 5),
#  (1, 9, 6),
#  (1, 9, 7),
#  (1, 9, 8),
#  (2, 1, 3),
#  (2, 1, 4),
#  (2, 1, 5),
#  (2, 1, 6),
#  (2, 1, 7),
#  (2, 1, 8),
#  (2, 1, 9),
#  (2, 3, 1),
#  (2, 3, 4),
#  (2, 3, 5),
#  (2, 3, 6),
#  (2, 3, 7),
#  (2, 3, 8),
#  (2, 3, 9),
#  (2, 4, 1),
# ...

# %%
len(p)
# Out:
# 504

# %%
special.perm(len(persons), 3)
# Out:
# 504.0
