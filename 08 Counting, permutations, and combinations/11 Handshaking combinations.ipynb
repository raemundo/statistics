# %% [markdown]
# # 11 Handshaking combinations

# %%
import itertools
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/counting-permutations-and-combinations/combinations-lib/v/handshaking-combinations?modal=1)

# %% [markdown]
# ![Handshaking combinations fig 1](./imgs/08-11-01.png)

# %%
persons = ['A', 'B', 'C', 'D']
shakes = [1, 2]

# %%
p = list(itertools.permutations(persons, len(shakes)))
c = list(itertools.combinations(persons, len(shakes)))

# %%
p
# Out:
# [('A', 'B'),
#  ('A', 'C'),
#  ('A', 'D'),
#  ('B', 'A'),
#  ('B', 'C'),
#  ('B', 'D'),
#  ('C', 'A'),
#  ('C', 'B'),
#  ('C', 'D'),
#  ('D', 'A'),
#  ('D', 'B'),
#  ('D', 'C')]

# %%
c
# Out:
# [('A', 'B'), ('A', 'C'), ('A', 'D'), ('B', 'C'), ('B', 'D'), ('C', 'D')]

# %%
len(p)
# Out:
# 12

# %%
len(c)
# Out:
# 6

# %%
special.perm(len(persons), len(shakes))
# Out:
# 12.0

# %%
special.comb(len(persons), len(shakes))
# Out:
# 6.0
