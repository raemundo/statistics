# %% [markdown]
# # 22 Mega millions jackpot probability

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, special

# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/statistics-probability/counting-permutations-and-combinations/combinatorics-probability/v/mega-millions-jackpot-probability?modal=1)

# %% [markdown]
# ![Mega millions jackpot probability fig 1](./imgs/08-22-01.png)

# %%
1 / special.comb(56, 5) * 46
# Out:
# 1.2042464872653551e-05
